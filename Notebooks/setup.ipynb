# %%
# %sql
create volume 035_ansh_e2e_flights_cata.raw.rawvolume

# %%
dbutils.fs.mkdirs('/Volumes/035_ansh_e2e_flights_cata/raw/rawvolume/rawdata')

# %%
dbutils.fs.mkdirs('/Volumes/035_ansh_e2e_flights_cata/raw/rawvolume/rawdata/bookings')
dbutils.fs.mkdirs('/Volumes/035_ansh_e2e_flights_cata/raw/rawvolume/rawdata/customers')
dbutils.fs.mkdirs('/Volumes/035_ansh_e2e_flights_cata/raw/rawvolume/rawdata/flights')
dbutils.fs.mkdirs('/Volumes/035_ansh_e2e_flights_cata/raw/rawvolume/rawdata/airports')
