# %% [markdown]
# ### Incremental Data Ingestion

# %%
# %sql
create volume 035_ansh_e2e_flights_cata.raw.bronze;
create volume 035_ansh_e2e_flights_cata.raw.silver;
create volume 035_ansh_e2e_flights_cata.raw.gold;

# %%
# %sql
create schema 035_ansh_e2e_flights_cata.bronze;
create schema 035_ansh_e2e_flights_cata.silver;
create schema 035_ansh_e2e_flights_cata.gold;

# %%
# %sql
create volume 035_ansh_e2e_flights_cata.bronze.bronzevolume;
create volume 035_ansh_e2e_flights_cata.silver.silvervolume;
create volume 035_ansh_e2e_flights_cata.gold.goldvolume;
